# %%
import json
import requests
from typing import List, Optional
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain_core.tools import tool
from langchain_tavily import TavilySearch

# %%
# =============================================================================
# 1) Estructuras Pydantic (contratos de salida de tools)
# =============================================================================

class SearchHit(BaseModel):
    title: str = Field(..., description="Título del resultado")
    url: str = Field(..., description="URL del resultado")
    content: Optional[str] = Field(None, description="Extracto o snippet del contenido")


class TavilySearchResult(BaseModel):
    query: str
    hits: List[SearchHit]
    source: str = "tavily"


class WeatherNowResult(BaseModel):
    city_input: str
    city_resolved: str
    temperature_c: float
    time: str
    source: str = "open-meteo"


class ToolError(BaseModel):
    error: str
    source: str

# %%
# =============================================================================
# 2) Tools (cada una devuelve JSON con la estructura definida)
# =============================================================================

# Tool A: búsqueda web (Tavily), pero envuelta con contrato Pydantic
tavily_client = TavilySearch(max_results=5)  # requiere TAVILY_API_KEY


@tool
def web_search(query: str) -> str:
    """
    Busca en la web y devuelve un JSON con estructura TavilySearchResult:
    { query, hits: [{title,url,content}], source }
    """
    try:
        raw = tavily_client.invoke(query)

        # raw suele traer "results" como lista de dicts con title/url/content
        results = raw.get("results", []) if isinstance(raw, dict) else []

        hits = []
        for r in results:
            hits.append(
                SearchHit(
                    title=str(r.get("title", "")),
                    url=str(r.get("url", "")),
                    content=r.get("content"),
                )
            )

        structured = TavilySearchResult(query=query, hits=hits)
        return structured.model_dump_json(ensure_ascii=False)

    except Exception as e:
        return ToolError(error=f"web_search failed: {e}", source="tavily").model_dump_json(
            ensure_ascii=False
        )


# Tool B: clima actual (Open-Meteo) con contrato Pydantic
@tool
def get_weather(city: str) -> str:
    """
    Obtiene la temperatura actual (°C) de una ciudad usando Open-Meteo.
    Devuelve un JSON con estructura WeatherNowResult.
    """
    try:
        # 1) Geocoding
        geo = requests.get(
            "https://geocoding-api.open-meteo.com/v1/search",
            params={"name": city, "count": 1, "language": "es", "format": "json"},
            timeout=15,
        ).json()

        if not geo.get("results"):
            return ToolError(error=f"No pude geocodificar '{city}'.", source="open-meteo").model_dump_json(
                ensure_ascii=False
            )

        r0 = geo["results"][0]
        lat, lon = r0["latitude"], r0["longitude"]
        resolved = f'{r0.get("name", city)}, {r0.get("country", "")}'.strip(", ")

        # 2) Current weather
        forecast = requests.get(
            "https://api.open-meteo.com/v1/forecast",
            params={
                "latitude": lat,
                "longitude": lon,
                "current_weather": True,
                "temperature_unit": "celsius",
            },
            timeout=15,
        ).json()

        cw = forecast.get("current_weather")
        if not cw:
            return ToolError(error="No pude obtener current_weather.", source="open-meteo").model_dump_json(
                ensure_ascii=False
            )

        structured = WeatherNowResult(
            city_input=city,
            city_resolved=resolved,
            temperature_c=float(cw.get("temperature")),
            time=str(cw.get("time")),
        )
        return structured.model_dump_json(ensure_ascii=False)

    except Exception as e:
        return ToolError(error=f"get_weather failed: {e}", source="open-meteo").model_dump_json(
            ensure_ascii=False
        )

# %%
# =============================================================================
# 3) Agente: decide qué tool usar (o ninguna)
# =============================================================================

def build_agent():
    llm = ChatOpenAI(model="gpt-4o", temperature=0)

    tools = [web_search, get_weather]

    system_prompt = (
        "Eres un agente en español con herramientas.\n\n"
        "Tienes dos tools:\n"
        "1) web_search(query): útil para clima PROMEDIO/TÍPICO, estaciones, mejor época, patrones generales.\n"
        "   Devuelve JSON con estructura TavilySearchResult: {query, hits:[{title,url,content}], source}.\n"
        "2) get_weather(city): útil para clima ACTUAL (ahora/en este momento/temperatura actual).\n"
        "   Devuelve JSON con estructura WeatherNowResult o ToolError.\n\n"
        "Reglas de decisión:\n"
        "- Si piden 'promedio', 'típico', 'en general', 'estaciones', 'mejor época' -> usa web_search.\n"
        "- Si piden 'ahora', 'en este momento', 'temperatura actual' -> usa get_weather.\n"
        "- Si la pregunta es conceptual -> no uses tools.\n"
        "- Si falta la ciudad, pregunta por la ciudad antes de usar tools.\n\n"
        "Instrucción clave:\n"
        "Cuando uses tools, lee el JSON devuelto y construye la respuesta final.\n"
        "Si hay error en JSON (ToolError), explícalo y ofrece alternativa."
    )

    return create_agent(
        model=llm,
        tools=tools,
        system_prompt=system_prompt,
        debug=True,  # muestra en consola cuándo llamó web_search o get_weather
    )


def ask(agent, question: str) -> str:
    result = agent.invoke({"messages": [HumanMessage(content=question)]})
    last = result["messages"][-1]
    return getattr(last, "content", last)

# %%
agent = build_agent()

print("\n" + "=" * 90)
print("DEMO 1 (promedio -> web_search)")
print(ask(agent, "¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)"))

print("\n" + "=" * 90)
print("DEMO 2 (ahora -> get_weather)")
print(ask(agent, "¿Cuál es la temperatura en este momento en Medellín?"))

print("\n" + "=" * 90)
print("DEMO 3 (ninguna tool)")
print(ask(agent, "Explícame la diferencia entre clima y tiempo atmosférico."))
# Out:
# ==========================================================================================
# DEMO 1 (promedio -> web_search)
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='9f993ca5-f349-419d-9f2d-2577f6908349')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 350, 'total_tokens': 376, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U58wJFis4AxXVPGrSHauZZpbCOe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-cb39-7143-828b-7501c65332f8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año temperaturas típicas lluvias'}, 'id': 'call_PNkb9EraPslh04L68ooRlyrd', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 26, 'total_tokens': 376, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='9f993ca5-f349-419d-9f2d-2577f6908349'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 350, 'total_tokens': 376, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U58wJFis4AxXVPGrSHauZZpbCOe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-cb39-7143-828b-7501c65332f8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año temperaturas típicas lluvias'}, 'id': 'call_PNkb9EraPslh04L68ooRlyrd', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 26, 'total_tokens': 376, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='{"query":"clima promedio Medellín durante el año temperaturas típicas lluvias","hits":[{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o","content":"En base a la puntuación de playa/piscina, la mejor época del año para visitar Medellín para las actividades de calor es desde *mediados de junio* hasta *principios de septiembre*  El clima en Medellín Comparar  Datos históricos:202620252024202320222021202020192018  El tiempo por mes en Medellín. El mes más cálido del año en Medellín es *julio*, con una temperatura máxima promedio de *35 °C* y mínima de *19 °C*. El mes más frío del año en Medellín es *enero*, con una temperatura mínima promedio de *3 °C* y máxima de *13 °C*. Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  La lluvia promedio (línea sólida) acumulada en un periodo de 31 días en una escala móvil, centrado en el día en cuestión, con las bandas de percentiles del 25º al 75º y del 10º al 90º. Velocidad promedio del viento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  El promedio de la velocidad media del viento por hora (línea gris oscuro), con las bandas de percentil 25º a 75º y 10º a 90º."},{"title":"Clima y mejor época para visitar Medellín - TikTok","url":"https://www.tiktok.com/@steph_andres_travel/video/7284730212447931654?lang=en","content":"Recordemos que en Medellín. hay lluvias frecuentes durante todo el año. Según lo que dicen, el mes más lluvioso, octubre, es cuando más llueve,"},{"title":"Climas y Temporadas en Colombia","url":"https://colombia.travel/es/informacion-practica/clima","content":"Las lluvias, aunque frecuentes, suelen concentrarse en las tardes. Medellín, por su parte, tiene un clima templado y primaveral todo el año, lo que la ha"},{"title":"¿Cuál es la temperatura promedio en Medellín? - Infobae","url":"https://www.infobae.com/colombia/2025/08/08/cual-es-la-temperatura-promedio-en-medellin/","content":"Medellín se caracteriza por un clima agradable, ni mucho calor, ni mucho frío, con temperaturas promedio que oscilan de los 16 a los 26 grados"},{"title":"Guía Completa Sobre El Clima En Medellín, Ideal Para Visitantes Y ...","url":"https://www.medellintoursvip.com.co/clima-en-medellin-ideal-para-visitantes/","content":"Las temperaturas en Medellín varían poco a lo largo del año. Los promedios oscilan entre 22°C y 28°C, lo que hace que el clima sea agradable y templado."}],"source":"tavily"}', name='web_search', id='fb69e4ca-ae96-43ac-ada0-d5583d0688b3', tool_call_id='call_PNkb9EraPslh04L68ooRlyrd')]}}
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='9f993ca5-f349-419d-9f2d-2577f6908349'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 350, 'total_tokens': 376, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U58wJFis4AxXVPGrSHauZZpbCOe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-cb39-7143-828b-7501c65332f8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año temperaturas típicas lluvias'}, 'id': 'call_PNkb9EraPslh04L68ooRlyrd', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 26, 'total_tokens': 376, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query":"clima promedio Medellín durante el año temperaturas típicas lluvias","hits":[{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o","content":"En base a la puntuación de playa/piscina, la mejor época del año para visitar Medellín para las actividades de calor es desde *mediados de junio* hasta *principios de septiembre*  El clima en Medellín Comparar  Datos históricos:202620252024202320222021202020192018  El tiempo por mes en Medellín. El mes más cálido del año en Medellín es *julio*, con una temperatura máxima promedio de *35 °C* y mínima de *19 °C*. El mes más frío del año en Medellín es *enero*, con una temperatura mínima promedio de *3 °C* y máxima de *13 °C*. Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  La lluvia promedio (línea sólida) acumulada en un periodo de 31 días en una escala móvil, centrado en el día en cuestión, con las bandas de percentiles del 25º al 75º y del 10º al 90º. Velocidad promedio del viento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  El promedio de la velocidad media del viento por hora (línea gris oscuro), con las bandas de percentil 25º a 75º y 10º a 90º."},{"title":"Clima y mejor época para visitar Medellín - TikTok","url":"https://www.tiktok.com/@steph_andres_travel/video/7284730212447931654?lang=en","content":"Recordemos que en Medellín. hay lluvias frecuentes durante todo el año. Según lo que dicen, el mes más lluvioso, octubre, es cuando más llueve,"},{"title":"Climas y Temporadas en Colombia","url":"https://colombia.travel/es/informacion-practica/clima","content":"Las lluvias, aunque frecuentes, suelen concentrarse en las tardes. Medellín, por su parte, tiene un clima templado y primaveral todo el año, lo que la ha"},{"title":"¿Cuál es la temperatura promedio en Medellín? - Infobae","url":"https://www.infobae.com/colombia/2025/08/08/cual-es-la-temperatura-promedio-en-medellin/","content":"Medellín se caracteriza por un clima agradable, ni mucho calor, ni mucho frío, con temperaturas promedio que oscilan de los 16 a los 26 grados"},{"title":"Guía Completa Sobre El Clima En Medellín, Ideal Para Visitantes Y ...","url":"https://www.medellintoursvip.com.co/clima-en-medellin-ideal-para-visitantes/","content":"Las temperaturas en Medellín varían poco a lo largo del año. Los promedios oscilan entre 22°C y 28°C, lo que hace que el clima sea agradable y templado."}],"source":"tavily"}', name='web_search', id='fb69e4ca-ae96-43ac-ada0-d5583d0688b3', tool_call_id ...
# [updates] {'model': {'messages': [AIMessage(content='El clima en Medellín es conocido por ser templado y primaveral durante todo el año. Las temperaturas promedio oscilan entre los 16°C y 26°C, lo que lo hace agradable y sin extremos de calor o frío. Las lluvias son frecuentes, especialmente en las tardes, y el mes más lluvioso suele ser octubre. En general, las temperaturas varían poco a lo largo del año, manteniéndose entre 22°C y 28°C. \n\nPara más detalles, puedes consultar [este enlace](https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 153, 'prompt_tokens': 1107, 'total_tokens': 1260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5AqdodzbTGrLCvjx5F5tx3sVrY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52bc-d3f4-7f90-8f49-692953e8c9fb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1107, 'output_tokens': 153, 'total_tokens': 1260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='9f993ca5-f349-419d-9f2d-2577f6908349'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 350, 'total_tokens': 376, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U58wJFis4AxXVPGrSHauZZpbCOe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-cb39-7143-828b-7501c65332f8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año temperaturas típicas lluvias'}, 'id': 'call_PNkb9EraPslh04L68ooRlyrd', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 26, 'total_tokens': 376, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query":"clima promedio Medellín durante el año temperaturas típicas lluvias","hits":[{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o","content":"En base a la puntuación de playa/piscina, la mejor época del año para visitar Medellín para las actividades de calor es desde *mediados de junio* hasta *principios de septiembre*  El clima en Medellín Comparar  Datos históricos:202620252024202320222021202020192018  El tiempo por mes en Medellín. El mes más cálido del año en Medellín es *julio*, con una temperatura máxima promedio de *35 °C* y mínima de *19 °C*. El mes más frío del año en Medellín es *enero*, con una temperatura mínima promedio de *3 °C* y máxima de *13 °C*. Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  La lluvia promedio (línea sólida) acumulada en un periodo de 31 días en una escala móvil, centrado en el día en cuestión, con las bandas de percentiles del 25º al 75º y del 10º al 90º. Velocidad promedio del viento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  El promedio de la velocidad media del viento por hora (línea gris oscuro), con las bandas de percentil 25º a 75º y 10º a 90º."},{"title":"Clima y mejor época para visitar Medellín - TikTok","url":"https://www.tiktok.com/@steph_andres_travel/video/7284730212447931654?lang=en","content":"Recordemos que en Medellín. hay lluvias frecuentes durante todo el año. Según lo que dicen, el mes más lluvioso, octubre, es cuando más llueve,"},{"title":"Climas y Temporadas en Colombia","url":"https://colombia.travel/es/informacion-practica/clima","content":"Las lluvias, aunque frecuentes, suelen concentrarse en las tardes. Medellín, por su parte, tiene un clima templado y primaveral todo el año, lo que la ha"},{"title":"¿Cuál es la temperatura promedio en Medellín? - Infobae","url":"https://www.infobae.com/colombia/2025/08/08/cual-es-la-temperatura-promedio-en-medellin/","content":"Medellín se caracteriza por un clima agradable, ni mucho calor, ni mucho frío, con temperaturas promedio que oscilan de los 16 a los 26 grados"},{"title":"Guía Completa Sobre El Clima En Medellín, Ideal Para Visitantes Y ...","url":"https://www.medellintoursvip.com.co/clima-en-medellin-ideal-para-visitantes/","content":"Las temperaturas en Medellín varían poco a lo largo del año. Los promedios oscilan entre 22°C y 28°C, lo que hace que el clima sea agradable y templado."}],"source":"tavily"}', name='web_search', id='fb69e4ca-ae96-43ac-ada0-d5583d0688b3', tool_call_id ...
# El clima en Medellín es conocido por ser templado y primaveral durante todo el año. Las temperaturas promedio oscilan entre los 16°C y 26°C, lo que lo hace agradable y sin extremos de calor o frío. Las lluvias son frecuentes, especialmente en las tardes, y el mes más lluvioso suele ser octubre. En general, las temperaturas varían poco a lo largo del año, manteniéndose entre 22°C y 28°C.
#
# Para más detalles, puedes consultar [este enlace](https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o).
#
# ==========================================================================================
# DEMO 2 (ahora -> get_weather)
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='9a21bc5c-6d9d-4204-90dd-f48887ad9d5a')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5DMee6b1vyt1lK9lIqdabBJBB2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-dda0-7f90-8cc0-bc5ef97cba1d-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_sFzatLexzrY7XOPY68nHVN8Z', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='9a21bc5c-6d9d-4204-90dd-f48887ad9d5a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5DMee6b1vyt1lK9lIqdabBJBB2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-dda0-7f90-8cc0-bc5ef97cba1d-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_sFzatLexzrY7XOPY68nHVN8Z', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='{"city_input":"Medellín","city_resolved":"Medellín, Colombia","temperature_c":22.5,"time":"2026-02-12T16:30","source":"open-meteo"}', name='get_weather', id='96c69eee-fa4d-41fa-80c5-80f0b96ae2c8', tool_call_id='call_sFzatLexzrY7XOPY68nHVN8Z')]}}
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='9a21bc5c-6d9d-4204-90dd-f48887ad9d5a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5DMee6b1vyt1lK9lIqdabBJBB2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-dda0-7f90-8cc0-bc5ef97cba1d-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_sFzatLexzrY7XOPY68nHVN8Z', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"city_input":"Medellín","city_resolved":"Medellín, Colombia","temperature_c":22.5,"time":"2026-02-12T16:30","source":"open-meteo"}', name='get_weather', id='96c69eee-fa4d-41fa-80c5-80f0b96ae2c8', tool_call_id='call_sFzatLexzrY7XOPY68nHVN8Z')]}
# [updates] {'model': {'messages': [AIMessage(content='La temperatura actual en Medellín, Colombia, es de 22.5°C.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 409, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5GF8qIxRvJIiOzuL3B0FlnJM4c', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52bc-eaab-7210-9e16-fb2bdd7b1e3b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 409, 'output_tokens': 18, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='9a21bc5c-6d9d-4204-90dd-f48887ad9d5a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5DMee6b1vyt1lK9lIqdabBJBB2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52bc-dda0-7f90-8cc0-bc5ef97cba1d-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_sFzatLexzrY7XOPY68nHVN8Z', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"city_input":"Medellín","city_resolved":"Medellín, Colombia","temperature_c":22.5,"time":"2026-02-12T16:30","source":"open-meteo"}', name='get_weather', id='96c69eee-fa4d-41fa-80c5-80f0b96ae2c8', tool_call_id='call_sFzatLexzrY7XOPY68nHVN8Z'), AIMessage(content='La temperatura actual en Medellín, Colombia, es de 22.5°C.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 409, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5GF8qIxRvJIiOzuL3B0FlnJM4c', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52bc-eaab-7210-9e16-fb2bdd7b1e3b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 409, 'output_tokens': 18, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# La temperatura actual en Medellín, Colombia, es de 22.5°C.
#
# ==========================================================================================
# DEMO 3 (ninguna tool)
# [values] {'messages': [HumanMessage(content='Explícame la diferencia entre clima y tiempo atmosférico.', additional_kwargs={}, response_metadata={}, id='8096b24d-6317-4e4e-9df4-d7cbd52282cb')]}
# [updates] {'model': {'messages': [AIMessage(content='El clima y el tiempo atmosférico son conceptos relacionados pero distintos:\n\n1. **Clima**:\n   - Se refiere a las condiciones atmosféricas promedio de una región durante un período prolongado, generalmente 30 años o más.\n   - Incluye patrones de temperatura, precipitación, humedad, viento y otras variables meteorológicas.\n   - Es más estable y cambia lentamente con el tiempo.\n   - Ejemplo: El clima de un desierto es árido y seco.\n\n2. **Tiempo atmosférico**:\n   - Se refiere a las condiciones atmosféricas en un momento y lugar específicos.\n   - Puede cambiar rápidamente, incluso de un día para otro o de una hora a otra.\n   - Incluye fenómenos como la lluvia, la nieve, la temperatura diaria, la nubosidad y el viento.\n   - Ejemplo: Hoy está lloviendo y hace frío.\n\nEn resumen, el clima es el promedio a largo plazo de las condiciones atmosféricas, mientras que el tiempo atmosférico es lo que experimentamos día a día.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 216, 'prompt_tokens': 341, 'total_tokens': 557, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5HGjnC0xJU0j9tEnSTDwmdj0nn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52bc-ed8f-7f60-9531-9dac6e366563-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 341, 'output_tokens': 216, 'total_tokens': 557, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Explícame la diferencia entre clima y tiempo atmosférico.', additional_kwargs={}, response_metadata={}, id='8096b24d-6317-4e4e-9df4-d7cbd52282cb'), AIMessage(content='El clima y el tiempo atmosférico son conceptos relacionados pero distintos:\n\n1. **Clima**:\n   - Se refiere a las condiciones atmosféricas promedio de una región durante un período prolongado, generalmente 30 años o más.\n   - Incluye patrones de temperatura, precipitación, humedad, viento y otras variables meteorológicas.\n   - Es más estable y cambia lentamente con el tiempo.\n   - Ejemplo: El clima de un desierto es árido y seco.\n\n2. **Tiempo atmosférico**:\n   - Se refiere a las condiciones atmosféricas en un momento y lugar específicos.\n   - Puede cambiar rápidamente, incluso de un día para otro o de una hora a otra.\n   - Incluye fenómenos como la lluvia, la nieve, la temperatura diaria, la nubosidad y el viento.\n   - Ejemplo: Hoy está lloviendo y hace frío.\n\nEn resumen, el clima es el promedio a largo plazo de las condiciones atmosféricas, mientras que el tiempo atmosférico es lo que experimentamos día a día.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 216, 'prompt_tokens': 341, 'total_tokens': 557, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f4835817c8', 'id': 'chatcmpl-D8U5HGjnC0xJU0j9tEnSTDwmdj0nn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52bc-ed8f-7f60-9531-9dac6e366563-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 341, 'output_tokens': 216, 'total_tokens': 557, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# El clima y el tiempo atmosférico son conceptos relacionados pero distintos:
#
# 1. **Clima**:
#    - Se refiere a las condiciones atmosféricas promedio de una región durante un período prolongado, generalmente 30 años o más.
#    - Incluye patrones de temperatura, precipitación, humedad, viento y otras variables meteorológicas.
#    - Es más estable y cambia lentamente con el tiempo.
#    - Ejemplo: El clima de un desierto es árido y seco.
#
# 2. **Tiempo atmosférico**:
#    - Se refiere a las condiciones atmosféricas en un momento y lugar específicos.
#    - Puede cambiar rápidamente, incluso de un día para otro o de una hora a otra.
#    - Incluye fenómenos como la lluvia, la nieve, la temperatura diaria, la nubosidad y el viento.
#    - Ejemplo: Hoy está lloviendo y hace frío.
#
# En resumen, el clima es el promedio a largo plazo de las condiciones atmosféricas, mientras que el tiempo atmosférico es lo que experimentamos día a día.
