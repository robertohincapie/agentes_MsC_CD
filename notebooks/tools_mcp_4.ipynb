# %%
import json
import requests
from typing import List, Optional
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain_core.tools import tool
from langchain_tavily import TavilySearch

# %%
# =============================================================================
# 1) Estructuras Pydantic (contratos de salida de tools)
# =============================================================================

class SearchHit(BaseModel):
    title: str = Field(..., description="Título del resultado")
    url: str = Field(..., description="URL del resultado")
    content: Optional[str] = Field(None, description="Extracto o snippet del contenido")


class TavilySearchResult(BaseModel):
    query: str
    hits: List[SearchHit]
    source: str = "tavily"


class WeatherNowResult(BaseModel):
    city_input: str
    city_resolved: str
    temperature_c: float
    time: str
    source: str = "open-meteo"


class ToolError(BaseModel):
    error: str
    source: str

# %%
# =============================================================================
# 2) Tools (cada una devuelve JSON con la estructura definida)
# =============================================================================

# Tool A: búsqueda web (Tavily), pero envuelta con contrato Pydantic
tavily_client = TavilySearch(max_results=5)  # requiere TAVILY_API_KEY


@tool
def web_search(query: str) -> str:
    """
    Busca en la web y devuelve un JSON con estructura TavilySearchResult:
    { query, hits: [{title,url,content}], source }
    """
    try:
        raw = tavily_client.invoke(query)

        # raw suele traer "results" como lista de dicts con title/url/content
        results = raw.get("results", []) if isinstance(raw, dict) else []

        hits = []
        for r in results:
            hits.append(
                SearchHit(
                    title=str(r.get("title", "")),
                    url=str(r.get("url", "")),
                    content=r.get("content"),
                )
            )

        structured = TavilySearchResult(query=query, hits=hits)
        return structured.model_dump_json(ensure_ascii=False)

    except Exception as e:
        return ToolError(error=f"web_search failed: {e}", source="tavily").model_dump_json(
            ensure_ascii=False
        )


# Tool B: clima actual (Open-Meteo) con contrato Pydantic
@tool
def get_weather(city: str) -> str:
    """
    Obtiene la temperatura actual (°C) de una ciudad usando Open-Meteo.
    Devuelve un JSON con estructura WeatherNowResult.
    """
    try:
        # 1) Geocoding
        geo = requests.get(
            "https://geocoding-api.open-meteo.com/v1/search",
            params={"name": city, "count": 1, "language": "es", "format": "json"},
            timeout=15,
        ).json()

        if not geo.get("results"):
            return ToolError(error=f"No pude geocodificar '{city}'.", source="open-meteo").model_dump_json(
                ensure_ascii=False
            )

        r0 = geo["results"][0]
        lat, lon = r0["latitude"], r0["longitude"]
        resolved = f'{r0.get("name", city)}, {r0.get("country", "")}'.strip(", ")

        # 2) Current weather
        forecast = requests.get(
            "https://api.open-meteo.com/v1/forecast",
            params={
                "latitude": lat,
                "longitude": lon,
                "current_weather": True,
                "temperature_unit": "celsius",
            },
            timeout=15,
        ).json()

        cw = forecast.get("current_weather")
        if not cw:
            return ToolError(error="No pude obtener current_weather.", source="open-meteo").model_dump_json(
                ensure_ascii=False
            )

        structured = WeatherNowResult(
            city_input=city,
            city_resolved=resolved,
            temperature_c=float(cw.get("temperature")),
            time=str(cw.get("time")),
        )
        return structured.model_dump_json(ensure_ascii=False)

    except Exception as e:
        return ToolError(error=f"get_weather failed: {e}", source="open-meteo").model_dump_json(
            ensure_ascii=False
        )

# %%
# =============================================================================
# 3) Agente: decide qué tool usar (o ninguna)
# =============================================================================

def build_agent():
    llm = ChatOpenAI(model="gpt-4o", temperature=0)

    tools = [web_search, get_weather]

    system_prompt = (
        "Eres un agente en español con herramientas.\n\n"
        "Tienes dos tools:\n"
        "1) web_search(query): útil para clima PROMEDIO/TÍPICO, estaciones, mejor época, patrones generales.\n"
        "   Devuelve JSON con estructura TavilySearchResult: {query, hits:[{title,url,content}], source}.\n"
        "2) get_weather(city): útil para clima ACTUAL (ahora/en este momento/temperatura actual).\n"
        "   Devuelve JSON con estructura WeatherNowResult o ToolError.\n\n"
        "Reglas de decisión:\n"
        "- Si piden 'promedio', 'típico', 'en general', 'estaciones', 'mejor época' -> usa web_search.\n"
        "- Si piden 'ahora', 'en este momento', 'temperatura actual' -> usa get_weather.\n"
        "- Si la pregunta es conceptual -> no uses tools.\n"
        "- Si falta la ciudad, pregunta por la ciudad antes de usar tools.\n\n"
        "Instrucción clave:\n"
        "Cuando uses tools, lee el JSON devuelto y construye la respuesta final.\n"
        "Si hay error en JSON (ToolError), explícalo y ofrece alternativa."
    )

    return create_agent(
        model=llm,
        tools=tools,
        system_prompt=system_prompt,
        debug=True,  # muestra en consola cuándo llamó web_search o get_weather
    )


def ask(agent, question: str) -> str:
    result = agent.invoke({"messages": [HumanMessage(content=question)]})
    last = result["messages"][-1]
    return getattr(last, "content", last)

# %%
agent = build_agent()

print("\n" + "=" * 90)
print("DEMO 1 (promedio -> web_search)")
print(ask(agent, "¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)"))

print("\n" + "=" * 90)
print("DEMO 2 (ahora -> get_weather)")
print(ask(agent, "¿Cuál es la temperatura en este momento en Medellín?"))

print("\n" + "=" * 90)
print("DEMO 3 (ninguna tool)")
print(ask(agent, "Explícame la diferencia entre clima y tiempo atmosférico."))
# Out:
# ==========================================================================================
# DEMO 1 (promedio -> web_search)
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='7624c069-d167-4528-a197-0f308339c91c')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 350, 'total_tokens': 371, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIBF5O26IKIn8LECLuhozYj1H05', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e8-e9a1-76a2-ad9b-4aa275929da8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año'}, 'id': 'call_bR7WIELvKZSiD8ZYiadhEGpT', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 21, 'total_tokens': 371, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='7624c069-d167-4528-a197-0f308339c91c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 350, 'total_tokens': 371, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIBF5O26IKIn8LECLuhozYj1H05', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e8-e9a1-76a2-ad9b-4aa275929da8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año'}, 'id': 'call_bR7WIELvKZSiD8ZYiadhEGpT', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 21, 'total_tokens': 371, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='{"query":"clima promedio Medellín durante el año","hits":[{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/22535/Clima-promedio-en-Medell","content":"Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  La lluvia promedio (línea sólida) acumulada en un periodo de 31 días en una escala móvil, centrado en el día en cuestión, con las bandas de percentiles del 25º al 75º y del 10º al 90º. La velocidad promedio del viento por hora en Medellín no varía considerablemente durante el año y permanece en un margen de más o menos *0,4 kilómetros por hora* de *2,8 kilómetros por hora*. Velocidad promedio del viento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  El promedio de la velocidad media del viento por hora (línea gris oscuro), con las bandas de percentil 25º a 75º y 10º a 90º. En este informe usamos una base de *10 °C* y un tope máximo de *30 °C*  Grados día de crecimiento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  Los grados día de crecimiento promedio acumulados en el transcurso del año, con las bandas de percentiles 25 a 75 y 10 a 90."},{"title":"Clima Medellín (Colombia) - Climate-Data.org","url":"https://es.climate-data.org/america-del-sur/colombia/antioquia/medellin-4088/","content":"La temperatura media en Medellín es 15.8 °C. La precipitación ... A lo largo del año, Medellín experimenta aproximadamente 2554.65 horas de insolación."},{"title":"Medellin climate: seasons, when to go, monthly averages","url":"https://www.climatestotravel.com/climate/colombia/medellin","content":"Medellin - Weather by month ... January is generally a warm to hot month. The average temperature is of 73 °F, with a minimum of 64 °F and a maximum of 82 °F."},{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o","content":"En base a la puntuación de playa/piscina, la mejor época del año para visitar Medellín para las actividades de calor es desde *mediados de junio* hasta *principios de septiembre*  El clima en Medellín Comparar  Datos históricos:202620252024202320222021202020192018  El tiempo por mes en Medellín. El mes más cálido del año en Medellín es *julio*, con una temperatura máxima promedio de *35 °C* y mínima de *19 °C*. El mes más frío del año en Medellín es *enero*, con una temperatura mínima promedio de *3 °C* y máxima de *13 °C*. Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  La lluvia promedio (línea sólida) acumulada en un periodo de 31 días en una escala móvil, centrado en el día en cuestión, con las bandas de percentiles del 25º al 75º y del 10º al 90º. Velocidad promedio del viento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  El promedio de la velocidad media del viento por hora (línea gris oscuro), con las bandas de percentil 25º a 75º y 10º a 90º."},{"title":"Guía Completa Sobre El Clima En Medellín, Ideal Para Visitantes Y ...","url":"https://www.medellintoursvip.com.co/clima-en-medellin-ideal-para-visitantes/","content":"Las temperaturas en Medellín varían poco a lo largo del año. Los promedios oscilan entre 22°C y 28°C, lo que hace que el clima sea agradable y templado."}],"source":"tavily"}', name='web_search', id='0859059c-69c2-48bc-a618-c927bd044696', tool_call_id='call_bR7WIELvKZSiD8ZYiadhEGpT')]}}
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='7624c069-d167-4528-a197-0f308339c91c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 350, 'total_tokens': 371, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIBF5O26IKIn8LECLuhozYj1H05', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e8-e9a1-76a2-ad9b-4aa275929da8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año'}, 'id': 'call_bR7WIELvKZSiD8ZYiadhEGpT', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 21, 'total_tokens': 371, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query":"clima promedio Medellín durante el año","hits":[{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/22535/Clima-promedio-en-Medell","content":"Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  La lluvia promedio (línea sólida) acumulada en un periodo de 31 días en una escala móvil, centrado en el día en cuestión, con las bandas de percentiles del 25º al 75º y del 10º al 90º. La velocidad promedio del viento por hora en Medellín no varía considerablemente durante el año y permanece en un margen de más o menos *0,4 kilómetros por hora* de *2,8 kilómetros por hora*. Velocidad promedio del viento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  El promedio de la velocidad media del viento por hora (línea gris oscuro), con las bandas de percentil 25º a 75º y 10º a 90º. En este informe usamos una base de *10 °C* y un tope máximo de *30 °C*  Grados día de crecimiento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  Los grados día de crecimiento promedio acumulados en el transcurso del año, con las bandas de percentiles 25 a 75 y 10 a 90."},{"title":"Clima Medellín (Colombia) - Climate-Data.org","url":"https://es.climate-data.org/america-del-sur/colombia/antioquia/medellin-4088/","content":"La temperatura media en Medellín es 15.8 °C. La precipitación ... A lo largo del año, Medellín experimenta aproximadamente 2554.65 horas de insolación."},{"title":"Medellin climate: seasons, when to go, monthly averages","url":"https://www.climatestotravel.com/climate/colombia/medellin","content":"Medellin - Weather by month ... January is generally a warm to hot month. The average temperature is of 73 °F, with a minimum of 64 °F and a maximum of 82 °F."},{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o","content":"En base a la puntuación de playa/piscina, la mejor época del año para visitar Medellín para las actividades de calor es desde *mediados de junio* hasta *principios de septiembre*  El clima en Medellín Comparar  Datos históricos:202620252024202320222021202020192018  El tiempo por mes en Medellín. El mes más cálido del año en Medellín es *julio*, con una temperatura máxima promedio de *35 °C* y mínima de *19 °C*. El mes más frío del año en Medellín es *enero*, con una temperatura mínima promedio de *3 °C* y máxima de *13 °C*. Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202 ...
# [updates] {'model': {'messages': [AIMessage(content='El clima en Medellín es bastante estable a lo largo del año, con temperaturas que varían poco. En promedio, las temperaturas oscilan entre 22°C y 28°C, lo que hace que el clima sea agradable y templado. La temperatura media anual es de aproximadamente 15.8°C.\n\nEn cuanto a las precipitaciones, Medellín experimenta lluvias durante todo el año, con un promedio anual de precipitaciones significativo. La ciudad recibe alrededor de 2554.65 horas de insolación al año, lo que indica una buena cantidad de días soleados.\n\nPara más detalles sobre el clima mensual y las mejores épocas para visitar, puedes consultar [este enlace](https://es.weatherspark.com/y/22535/Clima-promedio-en-Medell) o [este otro](https://es.climate-data.org/america-del-sur/colombia/antioquia/medellin-4088/).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 192, 'prompt_tokens': 1365, 'total_tokens': 1557, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIFIJsxw8yhae1d4CysKbFEDeBV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56e8-f938-7112-9408-6faa5908cda3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1365, 'output_tokens': 192, 'total_tokens': 1557, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cómo es en promedio el clima en Medellín durante el año? (temperaturas típicas y lluvias)', additional_kwargs={}, response_metadata={}, id='7624c069-d167-4528-a197-0f308339c91c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 350, 'total_tokens': 371, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIBF5O26IKIn8LECLuhozYj1H05', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e8-e9a1-76a2-ad9b-4aa275929da8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'clima promedio Medellín durante el año'}, 'id': 'call_bR7WIELvKZSiD8ZYiadhEGpT', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 350, 'output_tokens': 21, 'total_tokens': 371, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query":"clima promedio Medellín durante el año","hits":[{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/22535/Clima-promedio-en-Medell","content":"Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  La lluvia promedio (línea sólida) acumulada en un periodo de 31 días en una escala móvil, centrado en el día en cuestión, con las bandas de percentiles del 25º al 75º y del 10º al 90º. La velocidad promedio del viento por hora en Medellín no varía considerablemente durante el año y permanece en un margen de más o menos *0,4 kilómetros por hora* de *2,8 kilómetros por hora*. Velocidad promedio del viento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  El promedio de la velocidad media del viento por hora (línea gris oscuro), con las bandas de percentil 25º a 75º y 10º a 90º. En este informe usamos una base de *10 °C* y un tope máximo de *30 °C*  Grados día de crecimiento en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202320222021202020192018  Los grados día de crecimiento promedio acumulados en el transcurso del año, con las bandas de percentiles 25 a 75 y 10 a 90."},{"title":"Clima Medellín (Colombia) - Climate-Data.org","url":"https://es.climate-data.org/america-del-sur/colombia/antioquia/medellin-4088/","content":"La temperatura media en Medellín es 15.8 °C. La precipitación ... A lo largo del año, Medellín experimenta aproximadamente 2554.65 horas de insolación."},{"title":"Medellin climate: seasons, when to go, monthly averages","url":"https://www.climatestotravel.com/climate/colombia/medellin","content":"Medellin - Weather by month ... January is generally a warm to hot month. The average temperature is of 73 °F, with a minimum of 64 °F and a maximum of 82 °F."},{"title":"El clima en Medellín, el tiempo por mes, temperatura promedio ...","url":"https://es.weatherspark.com/y/34209/Clima-promedio-en-Medell%C3%ADn-Col%C3%B1a-durante-todo-el-a%C3%B1o","content":"En base a la puntuación de playa/piscina, la mejor época del año para visitar Medellín para las actividades de calor es desde *mediados de junio* hasta *principios de septiembre*  El clima en Medellín Comparar  Datos históricos:202620252024202320222021202020192018  El tiempo por mes en Medellín. El mes más cálido del año en Medellín es *julio*, con una temperatura máxima promedio de *35 °C* y mínima de *19 °C*. El mes más frío del año en Medellín es *enero*, con una temperatura mínima promedio de *3 °C* y máxima de *13 °C*. Promedio mensual de lluvia en Medellín Vínculo  Descargar  Comparar  Datos históricos:202620252024202 ...
# El clima en Medellín es bastante estable a lo largo del año, con temperaturas que varían poco. En promedio, las temperaturas oscilan entre 22°C y 28°C, lo que hace que el clima sea agradable y templado. La temperatura media anual es de aproximadamente 15.8°C.
#
# En cuanto a las precipitaciones, Medellín experimenta lluvias durante todo el año, con un promedio anual de precipitaciones significativo. La ciudad recibe alrededor de 2554.65 horas de insolación al año, lo que indica una buena cantidad de días soleados.
#
# Para más detalles sobre el clima mensual y las mejores épocas para visitar, puedes consultar [este enlace](https://es.weatherspark.com/y/22535/Clima-promedio-en-Medell) o [este otro](https://es.climate-data.org/america-del-sur/colombia/antioquia/medellin-4088/).
#
# ==========================================================================================
# DEMO 2 (ahora -> get_weather)
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='b0ae38ed-5ce0-406f-87c7-996116abd472')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIQxkWDq6j4AUWtnPhQONh4FF4D', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e9-26e0-7f03-904d-bc49190badcc-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_5sevhrjcUI60CoM8vvkG78RY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='b0ae38ed-5ce0-406f-87c7-996116abd472'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIQxkWDq6j4AUWtnPhQONh4FF4D', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e9-26e0-7f03-904d-bc49190badcc-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_5sevhrjcUI60CoM8vvkG78RY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='{"city_input":"Medellín","city_resolved":"Medellín, Colombia","temperature_c":17.6,"time":"2026-02-13T12:00","source":"open-meteo"}', name='get_weather', id='31f6bd24-6534-4bcb-9aec-eb489eeff437', tool_call_id='call_5sevhrjcUI60CoM8vvkG78RY')]}}
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='b0ae38ed-5ce0-406f-87c7-996116abd472'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIQxkWDq6j4AUWtnPhQONh4FF4D', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e9-26e0-7f03-904d-bc49190badcc-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_5sevhrjcUI60CoM8vvkG78RY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"city_input":"Medellín","city_resolved":"Medellín, Colombia","temperature_c":17.6,"time":"2026-02-13T12:00","source":"open-meteo"}', name='get_weather', id='31f6bd24-6534-4bcb-9aec-eb489eeff437', tool_call_id='call_5sevhrjcUI60CoM8vvkG78RY')]}
# [updates] {'model': {'messages': [AIMessage(content='La temperatura actual en Medellín, Colombia, es de 17.6°C.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 409, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIXzw1Qrwlz2YJvjgz3TDsKzvbl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56e9-3da2-7762-aef7-c52e4fcde671-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 409, 'output_tokens': 18, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuál es la temperatura en este momento en Medellín?', additional_kwargs={}, response_metadata={}, id='b0ae38ed-5ce0-406f-87c7-996116abd472'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 340, 'total_tokens': 356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIQxkWDq6j4AUWtnPhQONh4FF4D', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56e9-26e0-7f03-904d-bc49190badcc-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Medellín'}, 'id': 'call_5sevhrjcUI60CoM8vvkG78RY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 340, 'output_tokens': 16, 'total_tokens': 356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"city_input":"Medellín","city_resolved":"Medellín, Colombia","temperature_c":17.6,"time":"2026-02-13T12:00","source":"open-meteo"}', name='get_weather', id='31f6bd24-6534-4bcb-9aec-eb489eeff437', tool_call_id='call_5sevhrjcUI60CoM8vvkG78RY'), AIMessage(content='La temperatura actual en Medellín, Colombia, es de 17.6°C.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 409, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIXzw1Qrwlz2YJvjgz3TDsKzvbl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56e9-3da2-7762-aef7-c52e4fcde671-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 409, 'output_tokens': 18, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# La temperatura actual en Medellín, Colombia, es de 17.6°C.
#
# ==========================================================================================
# DEMO 3 (ninguna tool)
# [values] {'messages': [HumanMessage(content='Explícame la diferencia entre clima y tiempo atmosférico.', additional_kwargs={}, response_metadata={}, id='9863d95e-fb15-4eaa-af4e-6f47332fcf56')]}
# [updates] {'model': {'messages': [AIMessage(content='El clima y el tiempo atmosférico son conceptos relacionados pero distintos:\n\n1. **Clima**:\n   - Se refiere a las condiciones atmosféricas promedio de una región durante un período prolongado, generalmente 30 años o más.\n   - Incluye patrones de temperatura, precipitación, humedad, viento y otras variables meteorológicas.\n   - Es más estable y cambia lentamente con el tiempo.\n   - Ejemplo: El clima de un desierto es árido y seco.\n\n2. **Tiempo atmosférico**:\n   - Se refiere a las condiciones atmosféricas en un momento y lugar específicos.\n   - Puede cambiar rápidamente, de un día para otro o incluso de una hora a otra.\n   - Incluye fenómenos como la lluvia, la nieve, la temperatura diaria, la nubosidad y el viento.\n   - Ejemplo: Hoy está lloviendo y hace frío.\n\nEn resumen, el clima es el promedio a largo plazo de las condiciones atmosféricas, mientras que el tiempo atmosférico es lo que experimentamos día a día.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 216, 'prompt_tokens': 341, 'total_tokens': 557, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIbiUPOxamX8tdUZhoMuzxcVjFf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56e9-4ed6-7160-ac4a-bb0cbe90471d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 341, 'output_tokens': 216, 'total_tokens': 557, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Explícame la diferencia entre clima y tiempo atmosférico.', additional_kwargs={}, response_metadata={}, id='9863d95e-fb15-4eaa-af4e-6f47332fcf56'), AIMessage(content='El clima y el tiempo atmosférico son conceptos relacionados pero distintos:\n\n1. **Clima**:\n   - Se refiere a las condiciones atmosféricas promedio de una región durante un período prolongado, generalmente 30 años o más.\n   - Incluye patrones de temperatura, precipitación, humedad, viento y otras variables meteorológicas.\n   - Es más estable y cambia lentamente con el tiempo.\n   - Ejemplo: El clima de un desierto es árido y seco.\n\n2. **Tiempo atmosférico**:\n   - Se refiere a las condiciones atmosféricas en un momento y lugar específicos.\n   - Puede cambiar rápidamente, de un día para otro o incluso de una hora a otra.\n   - Incluye fenómenos como la lluvia, la nieve, la temperatura diaria, la nubosidad y el viento.\n   - Ejemplo: Hoy está lloviendo y hace frío.\n\nEn resumen, el clima es el promedio a largo plazo de las condiciones atmosféricas, mientras que el tiempo atmosférico es lo que experimentamos día a día.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 216, 'prompt_tokens': 341, 'total_tokens': 557, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_009ac31db9', 'id': 'chatcmpl-D8mIbiUPOxamX8tdUZhoMuzxcVjFf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56e9-4ed6-7160-ac4a-bb0cbe90471d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 341, 'output_tokens': 216, 'total_tokens': 557, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# El clima y el tiempo atmosférico son conceptos relacionados pero distintos:
#
# 1. **Clima**:
#    - Se refiere a las condiciones atmosféricas promedio de una región durante un período prolongado, generalmente 30 años o más.
#    - Incluye patrones de temperatura, precipitación, humedad, viento y otras variables meteorológicas.
#    - Es más estable y cambia lentamente con el tiempo.
#    - Ejemplo: El clima de un desierto es árido y seco.
#
# 2. **Tiempo atmosférico**:
#    - Se refiere a las condiciones atmosféricas en un momento y lugar específicos.
#    - Puede cambiar rápidamente, de un día para otro o incluso de una hora a otra.
#    - Incluye fenómenos como la lluvia, la nieve, la temperatura diaria, la nubosidad y el viento.
#    - Ejemplo: Hoy está lloviendo y hace frío.
#
# En resumen, el clima es el promedio a largo plazo de las condiciones atmosféricas, mientras que el tiempo atmosférico es lo que experimentamos día a día.
