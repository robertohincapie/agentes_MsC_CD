# %%
from enum import Enum
from typing import Literal

from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langchain.agents import create_agent

# %%
# -----------------------------
# 1) Tool tipada con Pydantic
# -----------------------------
class Operation(str, Enum):
    add = "add"
    sub = "sub"
    mul = "mul"
    div = "div"


class CalcInput(BaseModel):
    a: float = Field(..., description="Primer número")
    b: float = Field(..., description="Segundo número")
    op: Operation = Field(..., description="Operación: add|sub|mul|div")


@tool(args_schema=CalcInput)
def calculate(a: float, b: float, op: Operation) -> float:
    """Realiza una operación aritmética entre dos números y devuelve el resultado."""
    if op == Operation.add:
        return a + b
    if op == Operation.sub:
        return a - b
    if op == Operation.mul:
        return a * b
    if op == Operation.div:
        if b == 0:
            raise ValueError("División por cero no permitida.")
        return a / b
    raise ValueError(f"Operación no soportada: {op}")

# %%
# -----------------------------
# 2) Agente: decide usar tool o no
# -----------------------------
def build_agent():
    llm = ChatOpenAI(model="gpt-5", temperature=0)
    tools = [calculate]

    system_prompt = (
        "Eres un agente en español.\n"
        "Tienes disponible una herramienta llamada `calculate`.\n"
        "Regla:\n"
        "- Usa `calculate` SOLO cuando haya un cálculo explícito o cuando sea útil para evitar errores.\n"
        "- Si la pregunta es conceptual (sin cálculo), responde sin herramientas.\n"
        "Cuando uses la herramienta, interpreta el resultado y explica brevemente."
    )

    # En LangChain 1.2, create_agent recibe system_prompt (no prompt)
    agent = create_agent(
        model=llm,
        tools=tools,
        system_prompt=system_prompt,
        debug=True,  # <-- clave: muestra en consola tool calls y mensajes internos del runtime
    )
    return agent


def run_query(agent, text: str):
    result = agent.invoke({"messages": [HumanMessage(content=text)]})
    # El último mensaje suele ser la respuesta final al usuario
    last = result["messages"][-1]
    return getattr(last, "content", last)

# %%
agent = build_agent()
print("Agente creado. Probando con diferentes preguntas...")
# Caso 1: debería usar la tool
q1 = "Calcula 12.5 dividido entre 2.5. Usa la herramienta."
print("\n=== Pregunta 1 (debería usar tool) ===")
print(run_query(agent, q1))

# Caso 2: NO debería usar la tool (pregunta conceptual)
q2 = "¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos."
print("\n=== Pregunta 2 (no debería usar tool) ===")
print(run_query(agent, q2))

# Caso 3: el agente puede elegir tool por seguridad/precisión
q3 = "¿Cuánto es 19 * 37? No adivines: asegúrate del resultado."
print("\n=== Pregunta 3 (probablemente use tool) ===")
print(run_query(agent, q3))
# Out:
# Agente creado. Probando con diferentes preguntas...
#
# === Pregunta 1 (debería usar tool) ===
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='15b133c3-9c8a-4b59-9888-05629e5f274a')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eR8stClqkx9uGwxZRD2fsl4mhwh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-2383-79a2-a7d2-39427ced744f-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_2nnpyP0QXNe0hroXlVcRdPIB', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='15b133c3-9c8a-4b59-9888-05629e5f274a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eR8stClqkx9uGwxZRD2fsl4mhwh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-2383-79a2-a7d2-39427ced744f-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_2nnpyP0QXNe0hroXlVcRdPIB', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='5.0', name='calculate', id='3ab0d8fc-321c-4181-815e-fedd6449dd26', tool_call_id='call_2nnpyP0QXNe0hroXlVcRdPIB')]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='15b133c3-9c8a-4b59-9888-05629e5f274a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eR8stClqkx9uGwxZRD2fsl4mhwh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-2383-79a2-a7d2-39427ced744f-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_2nnpyP0QXNe0hroXlVcRdPIB', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='5.0', name='calculate', id='3ab0d8fc-321c-4181-815e-fedd6449dd26', tool_call_id='call_2nnpyP0QXNe0hroXlVcRdPIB')]}
# [updates] {'model': {'messages': [AIMessage(content='Resultado de la operación: 5.\n\nInterpretación: 12.5 ÷ 2.5 = 5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 298, 'total_tokens': 326, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRCMexkYDWXzUmfm6Q6wvxC2mCj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c551c-36d1-76f2-86c3-deb49acab4ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 298, 'output_tokens': 28, 'total_tokens': 326, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='15b133c3-9c8a-4b59-9888-05629e5f274a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eR8stClqkx9uGwxZRD2fsl4mhwh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-2383-79a2-a7d2-39427ced744f-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_2nnpyP0QXNe0hroXlVcRdPIB', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='5.0', name='calculate', id='3ab0d8fc-321c-4181-815e-fedd6449dd26', tool_call_id='call_2nnpyP0QXNe0hroXlVcRdPIB'), AIMessage(content='Resultado de la operación: 5.\n\nInterpretación: 12.5 ÷ 2.5 = 5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 298, 'total_tokens': 326, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRCMexkYDWXzUmfm6Q6wvxC2mCj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c551c-36d1-76f2-86c3-deb49acab4ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 298, 'output_tokens': 28, 'total_tokens': 326, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Resultado de la operación: 5.
#
# Interpretación: 12.5 ÷ 2.5 = 5.
#
# === Pregunta 2 (no debería usar tool) ===
# [values] {'messages': [HumanMessage(content='¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos.', additional_kwargs={}, response_metadata={}, id='6deace90-bc44-4e42-b167-28d35c987c70')]}
# [updates] {'model': {'messages': [AIMessage(content='Resumen corto:\n- Tool (herramienta): software concreto que “hace cosas”. Puede ser una app, script, CLI, plugin o servicio que ejecutas para lograr una tarea.\n- API (interfaz de programación): el contrato que define cómo un programa puede hablar con otro (métodos, parámetros, formatos, errores). No es una app en sí, es la “puerta” para acceder a capacidades.\n\nDiferencias clave:\n- Naturaleza:\n  - Tool: implementación práctica y utilizable.\n  - API: especificación/contrato de integración.\n- Interfaz:\n  - Tool: suele tener UI, CLI o flujo de uso directo.\n  - API: ofrece endpoints o funciones para ser llamadas por código (REST, GraphQL, gRPC, funciones de librería, etc.).\n- Usuario principal:\n  - Tool: personas o automatizaciones que la ejecutan.\n  - API: desarrolladores/código que la integran.\n- Relación:\n  - Una tool puede usar una o varias APIs por debajo.\n  - Muchas tools distintas pueden consumir la misma API.\n- Ejemplos:\n  - Tool: Git (CLI), Postman, Terraform, Photoshop, un script de backup.\n  - API: API de pagos de Stripe, API de mapas de Google, API del sistema operativo, API de una librería.\n\nNota en contexto de modelos de lenguaje:\n- “Tool” suele ser una acción o conector que el modelo puede invocar (por ejemplo, “calculate” o “buscar en la base de datos”), que a menudo llama a una API subyacente.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 912, 'prompt_tokens': 257, 'total_tokens': 1169, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRE2Ean5bp83SS4bFPHC64lY55z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c551c-3bd6-7803-aaf7-cf9566eac197-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 912, 'total_tokens': 1169, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}}
# [values] {'messages': [HumanMessage(content='¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos.', additional_kwargs={}, response_metadata={}, id='6deace90-bc44-4e42-b167-28d35c987c70'), AIMessage(content='Resumen corto:\n- Tool (herramienta): software concreto que “hace cosas”. Puede ser una app, script, CLI, plugin o servicio que ejecutas para lograr una tarea.\n- API (interfaz de programación): el contrato que define cómo un programa puede hablar con otro (métodos, parámetros, formatos, errores). No es una app en sí, es la “puerta” para acceder a capacidades.\n\nDiferencias clave:\n- Naturaleza:\n  - Tool: implementación práctica y utilizable.\n  - API: especificación/contrato de integración.\n- Interfaz:\n  - Tool: suele tener UI, CLI o flujo de uso directo.\n  - API: ofrece endpoints o funciones para ser llamadas por código (REST, GraphQL, gRPC, funciones de librería, etc.).\n- Usuario principal:\n  - Tool: personas o automatizaciones que la ejecutan.\n  - API: desarrolladores/código que la integran.\n- Relación:\n  - Una tool puede usar una o varias APIs por debajo.\n  - Muchas tools distintas pueden consumir la misma API.\n- Ejemplos:\n  - Tool: Git (CLI), Postman, Terraform, Photoshop, un script de backup.\n  - API: API de pagos de Stripe, API de mapas de Google, API del sistema operativo, API de una librería.\n\nNota en contexto de modelos de lenguaje:\n- “Tool” suele ser una acción o conector que el modelo puede invocar (por ejemplo, “calculate” o “buscar en la base de datos”), que a menudo llama a una API subyacente.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 912, 'prompt_tokens': 257, 'total_tokens': 1169, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRE2Ean5bp83SS4bFPHC64lY55z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c551c-3bd6-7803-aaf7-cf9566eac197-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 912, 'total_tokens': 1169, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}
# Resumen corto:
# - Tool (herramienta): software concreto que “hace cosas”. Puede ser una app, script, CLI, plugin o servicio que ejecutas para lograr una tarea.
# - API (interfaz de programación): el contrato que define cómo un programa puede hablar con otro (métodos, parámetros, formatos, errores). No es una app en sí, es la “puerta” para acceder a capacidades.
#
# Diferencias clave:
# - Naturaleza:
#   - Tool: implementación práctica y utilizable.
#   - API: especificación/contrato de integración.
# - Interfaz:
#   - Tool: suele tener UI, CLI o flujo de uso directo.
#   - API: ofrece endpoints o funciones para ser llamadas por código (REST, GraphQL, gRPC, funciones de librería, etc.).
# - Usuario principal:
#   - Tool: personas o automatizaciones que la ejecutan.
#   - API: desarrolladores/código que la integran.
# - Relación:
#   - Una tool puede usar una o varias APIs por debajo.
#   - Muchas tools distintas pueden consumir la misma API.
# - Ejemplos:
#   - Tool: Git (CLI), Postman, Terraform, Photoshop, un script de backup.
#   - API: API de pagos de Stripe, API de mapas de Google, API del sistema operativo, API de una librería.
#
# Nota en contexto de modelos de lenguaje:
# - “Tool” suele ser una acción o conector que el modelo puede invocar (por ejemplo, “calculate” o “buscar en la base de datos”), que a menudo llama a una API subyacente.
#
# === Pregunta 3 (probablemente use tool) ===
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='68e338f2-7062-45e3-b6e1-45a95c49d92a')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRcQqppuX7IegRLhFzE8qTwXV7r', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-9b45-7f22-adbd-f85ba48a64a1-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_X7fUojdmJrzXTNQUrXz9TOIg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='68e338f2-7062-45e3-b6e1-45a95c49d92a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRcQqppuX7IegRLhFzE8qTwXV7r', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-9b45-7f22-adbd-f85ba48a64a1-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_X7fUojdmJrzXTNQUrXz9TOIg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='703.0', name='calculate', id='f5b6ef70-6131-4a87-87ae-91f92109bc6b', tool_call_id='call_X7fUojdmJrzXTNQUrXz9TOIg')]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='68e338f2-7062-45e3-b6e1-45a95c49d92a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRcQqppuX7IegRLhFzE8qTwXV7r', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-9b45-7f22-adbd-f85ba48a64a1-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_X7fUojdmJrzXTNQUrXz9TOIg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='703.0', name='calculate', id='f5b6ef70-6131-4a87-87ae-91f92109bc6b', tool_call_id='call_X7fUojdmJrzXTNQUrXz9TOIg')]}
# [updates] {'model': {'messages': [AIMessage(content='19 × 37 = 703.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 297, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRf0iuomBBrvwLLu57ZCuR2kGqE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c551c-a881-70f0-afdf-22a17b336a51-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 11, 'total_tokens': 308, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='68e338f2-7062-45e3-b6e1-45a95c49d92a'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRcQqppuX7IegRLhFzE8qTwXV7r', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c551c-9b45-7f22-adbd-f85ba48a64a1-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_X7fUojdmJrzXTNQUrXz9TOIg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='703.0', name='calculate', id='f5b6ef70-6131-4a87-87ae-91f92109bc6b', tool_call_id='call_X7fUojdmJrzXTNQUrXz9TOIg'), AIMessage(content='19 × 37 = 703.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 297, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8eRf0iuomBBrvwLLu57ZCuR2kGqE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c551c-a881-70f0-afdf-22a17b336a51-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 11, 'total_tokens': 308, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# 19 × 37 = 703.
