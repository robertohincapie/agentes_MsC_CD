# %%
from enum import Enum
from typing import Literal

from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langchain.agents import create_agent

# %%
# -----------------------------
# 1) Tool tipada con Pydantic
# -----------------------------
class Operation(str, Enum):
    add = "add"
    sub = "sub"
    mul = "mul"
    div = "div"


class CalcInput(BaseModel):
    a: float = Field(..., description="Primer número")
    b: float = Field(..., description="Segundo número")
    op: Operation = Field(..., description="Operación: add|sub|mul|div")


@tool(args_schema=CalcInput)
def calculate(a: float, b: float, op: Operation) -> float:
    """Realiza una operación aritmética entre dos números y devuelve el resultado."""
    if op == Operation.add:
        return a + b
    if op == Operation.sub:
        return a - b
    if op == Operation.mul:
        return a * b
    if op == Operation.div:
        if b == 0:
            raise ValueError("División por cero no permitida.")
        return a / b
    raise ValueError(f"Operación no soportada: {op}")

# %%
# -----------------------------
# 2) Agente: decide usar tool o no
# -----------------------------
def build_agent():
    llm = ChatOpenAI(model="gpt-5", temperature=0)
    tools = [calculate]

    system_prompt = (
        "Eres un agente en español.\n"
        "Tienes disponible una herramienta llamada `calculate`.\n"
        "Regla:\n"
        "- Usa `calculate` SOLO cuando haya un cálculo explícito o cuando sea útil para evitar errores.\n"
        "- Si la pregunta es conceptual (sin cálculo), responde sin herramientas.\n"
        "Cuando uses la herramienta, interpreta el resultado y explica brevemente."
    )

    # En LangChain 1.2, create_agent recibe system_prompt (no prompt)
    agent = create_agent(
        model=llm,
        tools=tools,
        system_prompt=system_prompt,
        debug=True,  # <-- clave: muestra en consola tool calls y mensajes internos del runtime
    )
    return agent


def run_query(agent, text: str):
    result = agent.invoke({"messages": [HumanMessage(content=text)]})
    # El último mensaje suele ser la respuesta final al usuario
    last = result["messages"][-1]
    return getattr(last, "content", last)

# %%
agent = build_agent()
print("Agente creado. Probando con diferentes preguntas...")
# Caso 1: debería usar la tool
q1 = "Calcula 12.5 dividido entre 2.5. Usa la herramienta."
print("\n=== Pregunta 1 (debería usar tool) ===")
print(run_query(agent, q1))

# Caso 2: NO debería usar la tool (pregunta conceptual)
q2 = "¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos."
print("\n=== Pregunta 2 (no debería usar tool) ===")
print(run_query(agent, q2))

# Caso 3: el agente puede elegir tool por seguridad/precisión
q3 = "¿Cuánto es 19 * 37? No adivines: asegúrate del resultado."
print("\n=== Pregunta 3 (probablemente use tool) ===")
print(run_query(agent, q3))
# Out:
# Agente creado. Probando con diferentes preguntas...
#
# === Pregunta 1 (debería usar tool) ===
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='1f808d05-9db6-40ad-ba89-4cd67ac706cd')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 226, 'prompt_tokens': 257, 'total_tokens': 483, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVGBRiKheCUWteyT3JlSbuwhoD1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f5-47cc-7e03-a467-30767d7eed07-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_NoQxVf4K9CrnJe4whcBm8aHM', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 226, 'total_tokens': 483, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='1f808d05-9db6-40ad-ba89-4cd67ac706cd'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 226, 'prompt_tokens': 257, 'total_tokens': 483, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVGBRiKheCUWteyT3JlSbuwhoD1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f5-47cc-7e03-a467-30767d7eed07-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_NoQxVf4K9CrnJe4whcBm8aHM', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 226, 'total_tokens': 483, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='5.0', name='calculate', id='3e74f4b8-a393-4f62-bcbc-4adf77cccc72', tool_call_id='call_NoQxVf4K9CrnJe4whcBm8aHM')]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='1f808d05-9db6-40ad-ba89-4cd67ac706cd'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 226, 'prompt_tokens': 257, 'total_tokens': 483, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVGBRiKheCUWteyT3JlSbuwhoD1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f5-47cc-7e03-a467-30767d7eed07-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_NoQxVf4K9CrnJe4whcBm8aHM', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 226, 'total_tokens': 483, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}), ToolMessage(content='5.0', name='calculate', id='3e74f4b8-a393-4f62-bcbc-4adf77cccc72', tool_call_id='call_NoQxVf4K9CrnJe4whcBm8aHM')]}
# [updates] {'model': {'messages': [AIMessage(content='Resultado: 5\n\nExplicación: 12.5 ÷ 2.5 = 5. La herramienta devolvió 5.0, que equivale a 5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 298, 'total_tokens': 340, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVMKa8O85XKdIfZxNrwKSG8KFqw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f5-5fbe-7ef0-97aa-33c0064c58b4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 298, 'output_tokens': 42, 'total_tokens': 340, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='1f808d05-9db6-40ad-ba89-4cd67ac706cd'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 226, 'prompt_tokens': 257, 'total_tokens': 483, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVGBRiKheCUWteyT3JlSbuwhoD1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f5-47cc-7e03-a467-30767d7eed07-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_NoQxVf4K9CrnJe4whcBm8aHM', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 226, 'total_tokens': 483, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}), ToolMessage(content='5.0', name='calculate', id='3e74f4b8-a393-4f62-bcbc-4adf77cccc72', tool_call_id='call_NoQxVf4K9CrnJe4whcBm8aHM'), AIMessage(content='Resultado: 5\n\nExplicación: 12.5 ÷ 2.5 = 5. La herramienta devolvió 5.0, que equivale a 5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 298, 'total_tokens': 340, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVMKa8O85XKdIfZxNrwKSG8KFqw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f5-5fbe-7ef0-97aa-33c0064c58b4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 298, 'output_tokens': 42, 'total_tokens': 340, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Resultado: 5
#
# Explicación: 12.5 ÷ 2.5 = 5. La herramienta devolvió 5.0, que equivale a 5.
#
# === Pregunta 2 (no debería usar tool) ===
# [values] {'messages': [HumanMessage(content='¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos.', additional_kwargs={}, response_metadata={}, id='5cb86a90-d4ab-43fd-951d-ddc40268cf20')]}
# [updates] {'model': {'messages': [AIMessage(content='En general:\n\n- API (Application Programming Interface): es una interfaz formal que un sistema expone para que otros programas consuman sus funciones o datos. Suele definirse con endpoints, métodos, esquemas de petición/respuesta, autenticación, versionado y límites de uso. Ejemplos: REST, GraphQL, gRPC.\n\n- Tool (herramienta), en el contexto de agentes/LLMs: es una capacidad concreta que el agente puede invocar con un nombre y un esquema de entrada/salida. Detrás puede usar una API externa, código local, una base de datos o comandos del sistema. La tool encapsula la complejidad, valida entradas, maneja errores, oculta credenciales y aplica políticas.\n\nDiferencias clave:\n\n- Nivel de abstracción: la API es la interfaz genérica de un servicio; la tool es una acción específica preparada para el agente (p. ej., “traducir_texto”, “buscar_productos”).\n- Medio de invocación: la API se consume por red (HTTP, gRPC); la tool se invoca dentro del orquestador del agente y, a su vez, puede llamar a una o varias APIs o a código local.\n- Audiencia principal: la API está pensada para desarrolladores en general; la tool está pensada para que el modelo/agente la use de forma segura y guiada.\n- Acoplamiento y composición: una tool puede combinar múltiples APIs y lógica adicional; puedes cambiar la API subyacente sin cambiar cómo el agente llama a la tool.\n- Seguridad y gobernanza: la API requiere que el cliente gestione autenticación; la tool suele encapsular credenciales, permisos y registro de uso.\n\nEjemplos rápidos:\n- API: endpoint de Stripe para crear un cargo; endpoint de OpenWeather para el clima.\n- Tool: “procesar_pago” que recibe monto y moneda y por detrás usa Stripe; “obtener_clima(ciudad)” que llama a OpenWeather; o una tool local como “calculate” que hace aritmética sin salir a la red.\n\nCuándo usar cada una:\n- Si construyes software que integra servicios externos, usas APIs.\n- Si habilitas a un agente/LLM a ejecutar tareas controladas, defines tools que envuelven esas APIs y/o código interno.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1444, 'prompt_tokens': 257, 'total_tokens': 1701, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVNPjA3sZuPk56M38qBPq3K3yZZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f5-68d3-79c3-b99a-610475a4eb9a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 1444, 'total_tokens': 1701, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}})]}}
# [values] {'messages': [HumanMessage(content='¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos.', additional_kwargs={}, response_metadata={}, id='5cb86a90-d4ab-43fd-951d-ddc40268cf20'), AIMessage(content='En general:\n\n- API (Application Programming Interface): es una interfaz formal que un sistema expone para que otros programas consuman sus funciones o datos. Suele definirse con endpoints, métodos, esquemas de petición/respuesta, autenticación, versionado y límites de uso. Ejemplos: REST, GraphQL, gRPC.\n\n- Tool (herramienta), en el contexto de agentes/LLMs: es una capacidad concreta que el agente puede invocar con un nombre y un esquema de entrada/salida. Detrás puede usar una API externa, código local, una base de datos o comandos del sistema. La tool encapsula la complejidad, valida entradas, maneja errores, oculta credenciales y aplica políticas.\n\nDiferencias clave:\n\n- Nivel de abstracción: la API es la interfaz genérica de un servicio; la tool es una acción específica preparada para el agente (p. ej., “traducir_texto”, “buscar_productos”).\n- Medio de invocación: la API se consume por red (HTTP, gRPC); la tool se invoca dentro del orquestador del agente y, a su vez, puede llamar a una o varias APIs o a código local.\n- Audiencia principal: la API está pensada para desarrolladores en general; la tool está pensada para que el modelo/agente la use de forma segura y guiada.\n- Acoplamiento y composición: una tool puede combinar múltiples APIs y lógica adicional; puedes cambiar la API subyacente sin cambiar cómo el agente llama a la tool.\n- Seguridad y gobernanza: la API requiere que el cliente gestione autenticación; la tool suele encapsular credenciales, permisos y registro de uso.\n\nEjemplos rápidos:\n- API: endpoint de Stripe para crear un cargo; endpoint de OpenWeather para el clima.\n- Tool: “procesar_pago” que recibe monto y moneda y por detrás usa Stripe; “obtener_clima(ciudad)” que llama a OpenWeather; o una tool local como “calculate” que hace aritmética sin salir a la red.\n\nCuándo usar cada una:\n- Si construyes software que integra servicios externos, usas APIs.\n- Si habilitas a un agente/LLM a ejecutar tareas controladas, defines tools que envuelven esas APIs y/o código interno.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1444, 'prompt_tokens': 257, 'total_tokens': 1701, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mVNPjA3sZuPk56M38qBPq3K3yZZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f5-68d3-79c3-b99a-610475a4eb9a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 1444, 'total_tokens': 1701, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}})]}
# En general:
#
# - API (Application Programming Interface): es una interfaz formal que un sistema expone para que otros programas consuman sus funciones o datos. Suele definirse con endpoints, métodos, esquemas de petición/respuesta, autenticación, versionado y límites de uso. Ejemplos: REST, GraphQL, gRPC.
#
# - Tool (herramienta), en el contexto de agentes/LLMs: es una capacidad concreta que el agente puede invocar con un nombre y un esquema de entrada/salida. Detrás puede usar una API externa, código local, una base de datos o comandos del sistema. La tool encapsula la complejidad, valida entradas, maneja errores, oculta credenciales y aplica políticas.
#
# Diferencias clave:
#
# - Nivel de abstracción: la API es la interfaz genérica de un servicio; la tool es una acción específica preparada para el agente (p. ej., “traducir_texto”, “buscar_productos”).
# - Medio de invocación: la API se consume por red (HTTP, gRPC); la tool se invoca dentro del orquestador del agente y, a su vez, puede llamar a una o varias APIs o a código local.
# - Audiencia principal: la API está pensada para desarrolladores en general; la tool está pensada para que el modelo/agente la use de forma segura y guiada.
# - Acoplamiento y composición: una tool puede combinar múltiples APIs y lógica adicional; puedes cambiar la API subyacente sin cambiar cómo el agente llama a la tool.
# - Seguridad y gobernanza: la API requiere que el cliente gestione autenticación; la tool suele encapsular credenciales, permisos y registro de uso.
#
# Ejemplos rápidos:
# - API: endpoint de Stripe para crear un cargo; endpoint de OpenWeather para el clima.
# - Tool: “procesar_pago” que recibe monto y moneda y por detrás usa Stripe; “obtener_clima(ciudad)” que llama a OpenWeather; o una tool local como “calculate” que hace aritmética sin salir a la red.
#
# Cuándo usar cada una:
# - Si construyes software que integra servicios externos, usas APIs.
# - Si habilitas a un agente/LLM a ejecutar tareas controladas, defines tools que envuelven esas APIs y/o código interno.
#
# === Pregunta 3 (probablemente use tool) ===
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='1af28797-e264-47f8-be30-d4e3377df8ef')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 260, 'total_tokens': 354, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mW5sf7lsd4ofuwt1ftX24szvfzZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f6-0fb2-76e3-b67c-80f7d437e086-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_JRAR92PrIIqEOHJSHCHI8Xpp', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 94, 'total_tokens': 354, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='1af28797-e264-47f8-be30-d4e3377df8ef'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 260, 'total_tokens': 354, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mW5sf7lsd4ofuwt1ftX24szvfzZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f6-0fb2-76e3-b67c-80f7d437e086-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_JRAR92PrIIqEOHJSHCHI8Xpp', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 94, 'total_tokens': 354, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='703.0', name='calculate', id='42db1d78-6866-44e5-a69f-a25ba53f54d4', tool_call_id='call_JRAR92PrIIqEOHJSHCHI8Xpp')]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='1af28797-e264-47f8-be30-d4e3377df8ef'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 260, 'total_tokens': 354, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mW5sf7lsd4ofuwt1ftX24szvfzZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f6-0fb2-76e3-b67c-80f7d437e086-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_JRAR92PrIIqEOHJSHCHI8Xpp', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 94, 'total_tokens': 354, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), ToolMessage(content='703.0', name='calculate', id='42db1d78-6866-44e5-a69f-a25ba53f54d4', tool_call_id='call_JRAR92PrIIqEOHJSHCHI8Xpp')]}
# [updates] {'model': {'messages': [AIMessage(content='19 × 37 = 703.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 297, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mW77eN1OzPXefA5Kt0F8zsZ85Yx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f6-1c0b-7aa0-8fb4-e7a28ed3ff6e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 11, 'total_tokens': 308, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='1af28797-e264-47f8-be30-d4e3377df8ef'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 94, 'prompt_tokens': 260, 'total_tokens': 354, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mW5sf7lsd4ofuwt1ftX24szvfzZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c56f6-0fb2-76e3-b67c-80f7d437e086-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_JRAR92PrIIqEOHJSHCHI8Xpp', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 94, 'total_tokens': 354, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}), ToolMessage(content='703.0', name='calculate', id='42db1d78-6866-44e5-a69f-a25ba53f54d4', tool_call_id='call_JRAR92PrIIqEOHJSHCHI8Xpp'), AIMessage(content='19 × 37 = 703.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 297, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8mW77eN1OzPXefA5Kt0F8zsZ85Yx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56f6-1c0b-7aa0-8fb4-e7a28ed3ff6e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 11, 'total_tokens': 308, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# 19 × 37 = 703.
