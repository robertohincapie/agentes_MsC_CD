# %%
from enum import Enum
from typing import Literal

from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langchain.agents import create_agent

# %%
# -----------------------------
# 1) Tool tipada con Pydantic
# -----------------------------
class Operation(str, Enum):
    add = "add"
    sub = "sub"
    mul = "mul"
    div = "div"


class CalcInput(BaseModel):
    a: float = Field(..., description="Primer número")
    b: float = Field(..., description="Segundo número")
    op: Operation = Field(..., description="Operación: add|sub|mul|div")


@tool(args_schema=CalcInput)
def calculate(a: float, b: float, op: Operation) -> float:
    """Realiza una operación aritmética entre dos números y devuelve el resultado."""
    if op == Operation.add:
        return a + b
    if op == Operation.sub:
        return a - b
    if op == Operation.mul:
        return a * b
    if op == Operation.div:
        if b == 0:
            raise ValueError("División por cero no permitida.")
        return a / b
    raise ValueError(f"Operación no soportada: {op}")

# %%
# -----------------------------
# 2) Agente: decide usar tool o no
# -----------------------------
def build_agent():
    llm = ChatOpenAI(model="gpt-5", temperature=0)
    tools = [calculate]

    system_prompt = (
        "Eres un agente en español.\n"
        "Tienes disponible una herramienta llamada `calculate`.\n"
        "Regla:\n"
        "- Usa `calculate` SOLO cuando haya un cálculo explícito o cuando sea útil para evitar errores.\n"
        "- Si la pregunta es conceptual (sin cálculo), responde sin herramientas.\n"
        "Cuando uses la herramienta, interpreta el resultado y explica brevemente."
    )

    # En LangChain 1.2, create_agent recibe system_prompt (no prompt)
    agent = create_agent(
        model=llm,
        tools=tools,
        system_prompt=system_prompt,
        debug=True,  # <-- clave: muestra en consola tool calls y mensajes internos del runtime
    )
    return agent


def run_query(agent, text: str):
    result = agent.invoke({"messages": [HumanMessage(content=text)]})
    # El último mensaje suele ser la respuesta final al usuario
    last = result["messages"][-1]
    return getattr(last, "content", last)

# %%
agent = build_agent()
print("Agente creado. Probando con diferentes preguntas...")
# Caso 1: debería usar la tool
q1 = "Calcula 12.5 dividido entre 2.5. Usa la herramienta."
print("\n=== Pregunta 1 (debería usar tool) ===")
print(run_query(agent, q1))

# Caso 2: NO debería usar la tool (pregunta conceptual)
q2 = "¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos."
print("\n=== Pregunta 2 (no debería usar tool) ===")
print(run_query(agent, q2))

# Caso 3: el agente puede elegir tool por seguridad/precisión
q3 = "¿Cuánto es 19 * 37? No adivines: asegúrate del resultado."
print("\n=== Pregunta 3 (probablemente use tool) ===")
print(run_query(agent, q3))
# Out:
# Agente creado. Probando con diferentes preguntas...
#
# === Pregunta 1 (debería usar tool) ===
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='4993749a-ceb5-45af-bdfc-683ca6b178dc')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuDzXhvKNpB5tCU3FYiYDZr3mUX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-74a2-7162-ab48-ac96c3a8fd16-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_PmNdHfkYe3VUvtpzvXmdegm1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='4993749a-ceb5-45af-bdfc-683ca6b178dc'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuDzXhvKNpB5tCU3FYiYDZr3mUX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-74a2-7162-ab48-ac96c3a8fd16-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_PmNdHfkYe3VUvtpzvXmdegm1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='5.0', name='calculate', id='2919b002-ec04-4859-a95f-0bf07c57a2c6', tool_call_id='call_PmNdHfkYe3VUvtpzvXmdegm1')]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='4993749a-ceb5-45af-bdfc-683ca6b178dc'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuDzXhvKNpB5tCU3FYiYDZr3mUX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-74a2-7162-ab48-ac96c3a8fd16-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_PmNdHfkYe3VUvtpzvXmdegm1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='5.0', name='calculate', id='2919b002-ec04-4859-a95f-0bf07c57a2c6', tool_call_id='call_PmNdHfkYe3VUvtpzvXmdegm1')]}
# [updates] {'model': {'messages': [AIMessage(content='Resultado: 5\n\nInterpretación: 12.5 ÷ 2.5 = 5 porque 2.5 cabe cinco veces en 12.5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 298, 'total_tokens': 336, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuHTVY5BVqryFhnyaz2zMVi9EeD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52b2-8535-7713-8fb0-90397530edc4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 298, 'output_tokens': 38, 'total_tokens': 336, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Calcula 12.5 dividido entre 2.5. Usa la herramienta.', additional_kwargs={}, response_metadata={}, id='4993749a-ceb5-45af-bdfc-683ca6b178dc'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 257, 'total_tokens': 419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuDzXhvKNpB5tCU3FYiYDZr3mUX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-74a2-7162-ab48-ac96c3a8fd16-0', tool_calls=[{'name': 'calculate', 'args': {'a': 12.5, 'b': 2.5, 'op': 'div'}, 'id': 'call_PmNdHfkYe3VUvtpzvXmdegm1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 162, 'total_tokens': 419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='5.0', name='calculate', id='2919b002-ec04-4859-a95f-0bf07c57a2c6', tool_call_id='call_PmNdHfkYe3VUvtpzvXmdegm1'), AIMessage(content='Resultado: 5\n\nInterpretación: 12.5 ÷ 2.5 = 5 porque 2.5 cabe cinco veces en 12.5.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 298, 'total_tokens': 336, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuHTVY5BVqryFhnyaz2zMVi9EeD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52b2-8535-7713-8fb0-90397530edc4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 298, 'output_tokens': 38, 'total_tokens': 336, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Resultado: 5
#
# Interpretación: 12.5 ÷ 2.5 = 5 porque 2.5 cabe cinco veces en 12.5.
#
# === Pregunta 2 (no debería usar tool) ===
# [values] {'messages': [HumanMessage(content='¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos.', additional_kwargs={}, response_metadata={}, id='df665f8e-1f6c-44f7-984c-dad66fb254c7')]}
# [updates] {'model': {'messages': [AIMessage(content='En pocas palabras: una tool es una abstracción operativa que el asistente puede “llamar” como si fuera una función; una API es una interfaz de servicio (normalmente remota) para que software se comunique con otro software. Una tool puede envolver una o varias APIs, o ser algo local.\n\nPrincipales diferencias:\n- Qué son:\n  - Tool: un “conector” o función disponible para el asistente con un esquema de parámetros y resultados definidos para una tarea concreta.\n  - API: un conjunto de endpoints/protocolos para acceder a capacidades o datos de un servicio.\n- Alcance:\n  - Tool: orientada a una acción específica del asistente (p. ej., “buscar_hotel”).\n  - API: puede ofrecer muchas operaciones relacionadas (p. ej., reservas, pagos, usuarios).\n- Invocación:\n  - Tool: se llama dentro del flujo del asistente mediante “function calling” con parámetros tipados.\n  - API: se consume vía HTTP/REST/GraphQL/gRPC, SDKs, etc.\n- Infra/transporte:\n  - Tool: puede ser un wrapper sobre una API, un script local, una BBDD, o un servicio interno.\n  - API: típicamente un servicio en red con contratos públicos/privados.\n- Seguridad y control:\n  - Tool: el desarrollador del asistente decide qué expone, valida inputs y limita el alcance.\n  - API: maneja autenticación/autorización propias (tokens, claves, scopes), versionado, cuotas.\n- Granularidad y UX:\n  - Tool: más específica y diseñada para ser fácil de usar por el modelo.\n  - API: más general; requiere composición y manejo de detalles por parte del cliente.\n- Errores/contratos:\n  - Tool: devuelve errores ya mapeados a la lógica del asistente.\n  - API: códigos HTTP, esquemas de error propios, requisitos de idempotencia, etc.\n\nEjemplo:\n- Tool “calcular_envío(código_postal, peso)” que el asistente llama; internamente consulta varias APIs de paquetería.\n- API de paquetería “GET /v1/rates?zip=…&weight=…”, con autenticación y políticas de uso.\n\nRelación:\n- Toda tool podría usar una API, pero no toda tool es una API (puede ser local).\n- Cualquier API puede exponerse como tool para que el asistente la use de forma segura y guiada.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 909, 'prompt_tokens': 257, 'total_tokens': 1166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuJol5p4lVw1sQSmvEvPGZpCd4z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52b2-8dd6-7b23-92bd-6d72f7080d1e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 909, 'total_tokens': 1166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}}
# [values] {'messages': [HumanMessage(content='¿Qué diferencia hay entre una tool y una API? Responde sin hacer cálculos.', additional_kwargs={}, response_metadata={}, id='df665f8e-1f6c-44f7-984c-dad66fb254c7'), AIMessage(content='En pocas palabras: una tool es una abstracción operativa que el asistente puede “llamar” como si fuera una función; una API es una interfaz de servicio (normalmente remota) para que software se comunique con otro software. Una tool puede envolver una o varias APIs, o ser algo local.\n\nPrincipales diferencias:\n- Qué son:\n  - Tool: un “conector” o función disponible para el asistente con un esquema de parámetros y resultados definidos para una tarea concreta.\n  - API: un conjunto de endpoints/protocolos para acceder a capacidades o datos de un servicio.\n- Alcance:\n  - Tool: orientada a una acción específica del asistente (p. ej., “buscar_hotel”).\n  - API: puede ofrecer muchas operaciones relacionadas (p. ej., reservas, pagos, usuarios).\n- Invocación:\n  - Tool: se llama dentro del flujo del asistente mediante “function calling” con parámetros tipados.\n  - API: se consume vía HTTP/REST/GraphQL/gRPC, SDKs, etc.\n- Infra/transporte:\n  - Tool: puede ser un wrapper sobre una API, un script local, una BBDD, o un servicio interno.\n  - API: típicamente un servicio en red con contratos públicos/privados.\n- Seguridad y control:\n  - Tool: el desarrollador del asistente decide qué expone, valida inputs y limita el alcance.\n  - API: maneja autenticación/autorización propias (tokens, claves, scopes), versionado, cuotas.\n- Granularidad y UX:\n  - Tool: más específica y diseñada para ser fácil de usar por el modelo.\n  - API: más general; requiere composición y manejo de detalles por parte del cliente.\n- Errores/contratos:\n  - Tool: devuelve errores ya mapeados a la lógica del asistente.\n  - API: códigos HTTP, esquemas de error propios, requisitos de idempotencia, etc.\n\nEjemplo:\n- Tool “calcular_envío(código_postal, peso)” que el asistente llama; internamente consulta varias APIs de paquetería.\n- API de paquetería “GET /v1/rates?zip=…&weight=…”, con autenticación y políticas de uso.\n\nRelación:\n- Toda tool podría usar una API, pero no toda tool es una API (puede ser local).\n- Cualquier API puede exponerse como tool para que el asistente la use de forma segura y guiada.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 909, 'prompt_tokens': 257, 'total_tokens': 1166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuJol5p4lVw1sQSmvEvPGZpCd4z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52b2-8dd6-7b23-92bd-6d72f7080d1e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 257, 'output_tokens': 909, 'total_tokens': 1166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}
# En pocas palabras: una tool es una abstracción operativa que el asistente puede “llamar” como si fuera una función; una API es una interfaz de servicio (normalmente remota) para que software se comunique con otro software. Una tool puede envolver una o varias APIs, o ser algo local.
#
# Principales diferencias:
# - Qué son:
#   - Tool: un “conector” o función disponible para el asistente con un esquema de parámetros y resultados definidos para una tarea concreta.
#   - API: un conjunto de endpoints/protocolos para acceder a capacidades o datos de un servicio.
# - Alcance:
#   - Tool: orientada a una acción específica del asistente (p. ej., “buscar_hotel”).
#   - API: puede ofrecer muchas operaciones relacionadas (p. ej., reservas, pagos, usuarios).
# - Invocación:
#   - Tool: se llama dentro del flujo del asistente mediante “function calling” con parámetros tipados.
#   - API: se consume vía HTTP/REST/GraphQL/gRPC, SDKs, etc.
# - Infra/transporte:
#   - Tool: puede ser un wrapper sobre una API, un script local, una BBDD, o un servicio interno.
#   - API: típicamente un servicio en red con contratos públicos/privados.
# - Seguridad y control:
#   - Tool: el desarrollador del asistente decide qué expone, valida inputs y limita el alcance.
#   - API: maneja autenticación/autorización propias (tokens, claves, scopes), versionado, cuotas.
# - Granularidad y UX:
#   - Tool: más específica y diseñada para ser fácil de usar por el modelo.
#   - API: más general; requiere composición y manejo de detalles por parte del cliente.
# - Errores/contratos:
#   - Tool: devuelve errores ya mapeados a la lógica del asistente.
#   - API: códigos HTTP, esquemas de error propios, requisitos de idempotencia, etc.
#
# Ejemplo:
# - Tool “calcular_envío(código_postal, peso)” que el asistente llama; internamente consulta varias APIs de paquetería.
# - API de paquetería “GET /v1/rates?zip=…&weight=…”, con autenticación y políticas de uso.
#
# Relación:
# - Toda tool podría usar una API, pero no toda tool es una API (puede ser local).
# - Cualquier API puede exponerse como tool para que el asistente la use de forma segura y guiada.
#
# === Pregunta 3 (probablemente use tool) ===
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='58b320f3-f3f4-41ad-9515-f67c20dfdfc9')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuhbKGfyHKC0KXuA0CtGhbny5bM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-ecdf-79b1-83c0-c3fec6dfeab8-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_PoUalYRjAmXbFGx9VgF8TGoD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='58b320f3-f3f4-41ad-9515-f67c20dfdfc9'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuhbKGfyHKC0KXuA0CtGhbny5bM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-ecdf-79b1-83c0-c3fec6dfeab8-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_PoUalYRjAmXbFGx9VgF8TGoD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='703.0', name='calculate', id='c72c2f60-7c69-4b93-9ae5-4665cce5e23c', tool_call_id='call_PoUalYRjAmXbFGx9VgF8TGoD')]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='58b320f3-f3f4-41ad-9515-f67c20dfdfc9'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuhbKGfyHKC0KXuA0CtGhbny5bM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-ecdf-79b1-83c0-c3fec6dfeab8-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_PoUalYRjAmXbFGx9VgF8TGoD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='703.0', name='calculate', id='c72c2f60-7c69-4b93-9ae5-4665cce5e23c', tool_call_id='call_PoUalYRjAmXbFGx9VgF8TGoD')]}
# [updates] {'model': {'messages': [AIMessage(content='19 × 37 = 703.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 297, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TunHoJYvphmGexTafoA64cUAII2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52b3-0426-78d3-bdd3-fd799490c96e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 11, 'total_tokens': 308, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='¿Cuánto es 19 * 37? No adivines: asegúrate del resultado.', additional_kwargs={}, response_metadata={}, id='58b320f3-f3f4-41ad-9515-f67c20dfdfc9'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 260, 'total_tokens': 418, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TuhbKGfyHKC0KXuA0CtGhbny5bM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c52b2-ecdf-79b1-83c0-c3fec6dfeab8-0', tool_calls=[{'name': 'calculate', 'args': {'a': 19, 'b': 37, 'op': 'mul'}, 'id': 'call_PoUalYRjAmXbFGx9VgF8TGoD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 260, 'output_tokens': 158, 'total_tokens': 418, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}), ToolMessage(content='703.0', name='calculate', id='c72c2f60-7c69-4b93-9ae5-4665cce5e23c', tool_call_id='call_PoUalYRjAmXbFGx9VgF8TGoD'), AIMessage(content='19 × 37 = 703.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 297, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8TunHoJYvphmGexTafoA64cUAII2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c52b3-0426-78d3-bdd3-fd799490c96e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 11, 'total_tokens': 308, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# 19 × 37 = 703.
